# %% [markdown]
# 1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
class Circle:

    def area(self,r):
        return 3.14 * r * r
    
    def perimeter(self,r):
        return 2 * 3.14 * r
    
    
circle = Circle()
print(circle.area(6))
print(circle.perimeter(7))
# Out:
# 113.03999999999999
# 43.96

# %% [markdown]
# 2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
from datetime import datetime

class Person:

    def __init__(self,name,country,dob):
        self.name = name
        self.country = country
        self.dob = dob

    def person_age(self):
        dob = datetime.strptime(self.dob, "%Y-%m-%d")

        today = datetime.today()

        age = today.year - dob.year

        if (today.month,today.day) < (dob.month, dob.day):
            age -= 1

        return age
    
person = Person('Himanshu','India','2001-06-23')
print(person.person_age())
# Out:
# 24

# %% [markdown]
# 3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:

    def add(self,a,b):
        return a+b
    
    def sub(self,a,b):
        return a-b
    
    def multiply(self,a,b):
        return a*b
    
    def div(self,a,b):
        return a/b
    
    def mod(self,a,b):
        return a%2
    
cal = Calculator()

print(cal.add(5,7))
print(cal.sub(10,5))
print(cal.multiply(5,6))
print(cal.div(20,2))
print(cal.mod(55,4))
# Out:
# 12
# 5
# 30
# 10.0
# 1

# %% [markdown]
# 4. Write a Python program to create a class that represents a shape. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like circle, triangle, and square.

# %%
class Shapes:

    class Circle:
         
        def area(self,r):
         return 3.14 * r * r
    
        def perimeter(self,r):
         return 2 * 3.14 * r
        

    class Triangle:
       
       def area(self,b,h):
          return 1/2 * b * h
       
       def perimeter(self,a,b,c):
          return a+b+c
       
    class Square:
       
       def area(self,s):
          return s**2
       
       def perimeter(self,s):
          return 4 * s
       

shape = Shapes()

circle = shape.Circle()
print(circle.area(6))
print(circle.perimeter(8))

triangle = shape.Triangle()
print(triangle.area(5,7))
print(triangle.perimeter(3,4,5))

square = shape.Square()
print(square.area(4))
print(square.perimeter(5))
# Out:
# 113.03999999999999
# 50.24
# 17.5
# 12
# 16
# 20

# %% [markdown]
# 5. Write a Python program to create a class representing a binary search tree. Include methods for inserting and searching for elements in the binary tree.

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


class BST:
    def __init__(self):
        self.root = None


    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            self._insert(self.root, value)

    def _insert(self, node, value):
        if value < node.value:
            if node.left is None:
                node.left = Node(value)
            else:
                self._insert(node.left, value)
        else:
            if node.right is None:
                node.right = Node(value)
            else:
                self._insert(node.right, value)

    
    def search(self, value):
        return self._search(self.root, value)

    def _search(self, node, value):
        if node is None:
            return False
        if node.value == value:
            return True
        elif value < node.value:
            return self._search(node.left, value)
        else:
            return self._search(node.right, value)



tree = BST()

tree.insert(50)
tree.insert(30)
tree.insert(70)
tree.insert(20)
tree.insert(40)

print(tree.search(40))  # True
print(tree.search(90))  # False
# Out:
# True
# False

# %% [markdown]
# 6. Write a Python program to create a class representing a stack data structure. Include methods for pushing and popping elements.

# %%
class Stack:

    def __init__(self):
        self.stack = []

    def push(self,el):
        self.stack.append(el)
        print(el,"pushed")

    def pop(self):
        if self.stack == 0:
            print("Stack is empty")
        else:
            print(self.stack.pop(), "is poped")
    
    def display(self):
        print(self.stack)

stack = Stack()

stack.push(30)
stack.push(40)
stack.push(90)
stack.display()

stack.pop()
stack.display()
# Out:
# 30 pushed
# 40 pushed
# 90 pushed
# [30, 40, 90]
# 90 is poped
# [30, 40]

# %% [markdown]
# 7. Write a Python program to create a class representing a linked list data structure. Include methods for displaying linked list data, inserting and deleting nodes.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None

    # Insert at end
    def insert(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    def delete(self, key):
        temp = self.head

        # if head itself holds the key
        if temp and temp.data == key:
            self.head = temp.next
            temp = None
            return

        prev = None
        while temp and temp.data != key:
            prev = temp
            temp = temp.next

        if temp is None:
            print("Value not found")
            return

        prev.next = temp.next
        temp = None

    def display(self):
        temp = self.head
        while temp:
            print(temp.data, end=" -> ")
            temp = temp.next
        print("None")


ll = LinkedList()

ll.insert(10)
ll.insert(20)
ll.insert(30)

ll.display()

ll.delete(20)
ll.display()
# Out:
# 10 -> 20 -> 30 -> None
# 10 -> 30 -> None

# %% [markdown]
# 8. Write a Python program to create a class representing a shopping cart. Include methods for adding and removing items, and calculating the total price.

# %%
class Cart:

    def __init__(self):
        self.__item_list = []

    def add_item(self,item,price):
        self.__item_list.append((item,price))
        print(item, "is added")

    def remove_item(self,item):
        for i in self.__item_list:
            if i[0] == item:
                self.__item_list.remove(i)
                print(item,"is removed")

    def calculate_total_price(self):
        total = 0
        for item,price in self.__item_list:
            total = total + price

        return total
    

cart = Cart()

cart.add_item("chocolate",180)

cart.add_item("Greek Yogurt",60)

cart.add_item("oats",350)

cart.remove_item("Greek Yogurt")

print("Total price :",cart.calculate_total_price())
# Out:
# chocolate is added
# Greek Yogurt is added
# oats is added
# Greek Yogurt is removed
# Total price : 530

# %% [markdown]
# 9. Write a Python program to create a class representing a stack data structure. Include methods for pushing, popping and displaying elements.

# %%
class Stack:

    def __init__(self):
        self.stack = []

    def push(self,el):
        self.stack.append(el)
        print(el,"pushed")

    def pop(self):
        if self.stack == 0:
            print("Stack is empty")
        else:
            print(self.stack.pop(), "is poped")
    
    def display(self):
        print(self.stack)

stack = Stack()

stack.push(70)
stack.push(60)
stack.push(96)
stack.push(90)
stack.push(100)
stack.display()

stack.pop()
stack.display()
# Out:
# 70 pushed
# 60 pushed
# 96 pushed
# 90 pushed
# 100 pushed
# [70, 60, 96, 90, 100]
# 100 is poped
# [70, 60, 96, 90]

# %% [markdown]
# 10. Write a Python program to create a class representing a queue data structure. Include methods for enqueueing and dequeueing elements.

# %%
class Queue:

    def __init__(self):
        self.queue = []

    def enqeue(self,el):
        self.queue.append(el)

    def deqeue(self):
        if len(self.queue) == 0:
            print("Queue is empty")
        else:
            print(self.queue.pop(0),"popped")

    def display(self):
        print(self.queue)

queue = Queue()

queue.enqeue(30)
queue.enqeue(50)
queue.enqeue(60)
queue.enqeue(90)
queue.enqeue(100)

queue.display()

queue.deqeue()

queue.display()
# Out:
# [30, 50, 60, 90, 100]
# 30 popped
# [50, 60, 90, 100]

# %% [markdown]
# 11. Write a Python program to create a class representing a bank. Include methods for managing customer accounts and transactions.
# 	Create a Python class called BankAccount which represents a bank account, having as attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.
# 	Create a constructor with parameters: accountNumber, name, balance.
# 	Create a Deposit() method which manages the deposit actions.
# 	Create a Withdrawal() method which manages withdrawals actions.
# 	Create an bankFees() method to apply the bank fees with a percentage of 5% of the balance account.
# 	Create a display() method to display account details. Give the complete code for the BankAccount class.

# %%
class BankAccount:

    def __init__(self,accountNumber,name,balance):
        self.accountNumber = accountNumber
        self.name = name
        self.balance = balance
        # self.__database = {}
        self.__menu()

    def __menu(self):
        while True:
            choice = input('''
            1. Deposit
            2. Withdrawal
            3. Check Account Details
            4. Exit
            Enter choice: ''')

            if choice == '1':
                self.deposit()
            elif choice == '2':
                self.withdrawal()
            elif choice == '3':
                self.customer_details()
            elif choice == '4':
                print("Thank you!")
                break
            else:
                print("Invalid choice")

    def deposit(self):
        
        name = input("Enter your name: ")
        acc_num = input("Enter your account number: ")
        dep = int(input("Enter the amount: "))

        if name == self.name and acc_num == self.accountNumber:
                self.balance += dep
                self.bankfees()
                print("Avaiable balance: ", self.balance)
        else:
            print("Invalid details")
        self.__menu()


    def withdrawal(self):
        name = input("Enter your name: ")
        acc_num = input("Enter your account number: ")
        amt = int(input("Enter the amount: "))

        if name == self.name and acc_num == self.accountNumber:
            if amt <= self.balance:
                self.balance -= amt
                self.bankfees()
                print("Avaiable balance: ", self.balance)
            else:
                print("Insufficient balance")
        else:
            print("Invalid details")
        self.__menu()


    def customer_details(self):
        print("Name: ", self.name)
        print("Account Number: ", self.accountNumber)
        print("Avaiable balance: ", self.balance)
        self.__menu()

    def bankfees(self):
        fee = self.balance * 0.05
        self.balance -= fee
        print("Bank fees: ", fee)
        # print("Updated balance: ", self.balance)

b = BankAccount('123456','Himanshu',10000)
# Out:
# Name:  Himanshu
# Account Number:  123456
# Avaiable balance:  10000
# Thank you!
# Thank you!

# %% [markdown]
# 12. Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# 	Example 1:
#
# 	Approach:
#
# 	Create a class named FlashCard.
# 	Initialize dictionary fruits using init() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
# 	Now randomly choose a pair from fruits by using random module and store the key in variable fruit and value in variable color.
# 	Now prompt the user to answer the color of the randomly chosen fruit.
# 	If correct print correct else print wrong.
# 	Output:
#
# 	welcome to fruit quiz
# 	What is the color of Strawberries
# 	pink
# 	Correct answer
# 	Enter 0, if you want to play again: 0
# 	What is the color of watermelon
# 	green
# 	Correct answer
# 	Enter 0, if you want to play again: 1

# %%
import random
class Flashcard:

    def __init__(self):
        fruits = {"Banana": "yellow", "Strawberries": "pink","Watermelon":"green","Orange":"orange","Apple":"red"}

        fruit, color = random.choice(list(fruits.items()))
        
        print("Welcome to the fruit quiz")

        user_input = input(f"What is the color of {fruit}?")

        if user_input == color:
            print("Correct answer")
        else:
            print("wrong answer")

f = Flashcard()
# Out:
# Welcome to the fruit quiz
# Correct answer

# %% [markdown]
# 13. TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name, technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:
#
# 	eligibility criteria:
# 	if experience is more than 3 years, average feedback should be 4.5 or more
# 	if experience is 3 years or less, average feedback should be 4 or more
# 	he/she should posses the technology skill for the course
# 	Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.
#
# 	Note:
#
# 	Consider all instance variables to be private and methods to be public.
# 	An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
# 	check_eligibility(): Return true if eligibility criteria is satisfied by the instructor. Else, return false
# 	allocate_course(technology): Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
# 	Represent a few objects of the class, initialize instance variables using setter methods, invoke appropriate methods and test your program.

# %%
class TraningCenter:

    def __init__(self):
        self.__name = None
        self.__technology_skill = []
        self.__experience = None
        self.__avg_feedback = None

    def set_name(self,name):
        self.__name = name

    def set_technology_skills(self,techno_skills):
        self.__technology_skill = techno_skills

    def set_experience(self,exp):
        self.__experience = exp
    
    def set_avg_feedback(self,avg_feedback):
        self.__avg_feedback = avg_feedback

    def check_eligibility(self):
        if self.__experience > 3 and self.__avg_feedback >= 4.5:
            return True
        elif self.__experience <= 3 and self.__avg_feedback >= 4:
            return True
        else:
            return False
        
    def allocate_course(self,technology):
        if self.check_eligibility() and technology in self.__technology_skill:
            return True
        else:
            return False

t1 = TraningCenter() 

t1.set_name("Himanshu")
t1.set_technology_skills(["Python","Java","C++"])
t1.set_experience(4)
t1.set_avg_feedback(4.7)
print(t1.check_eligibility())
print(t1.allocate_course("Python"))

t2 = TraningCenter()
t2.set_name("Aman")
t2.set_technology_skills(["C++","SQL"])
t2.set_experience(3)
t2.set_avg_feedback(3.6)
print(t2.check_eligibility())
print(t2.allocate_course("SQL"))
# Out:
# True
# True
# False
# False

# %% [markdown]
# 14. Write a program that uses datetime module within a class. Enter manufacturing date and expiry date of the product. The program must display the years, months and days that are left for expiry.

# %%
from datetime import datetime

class Product:

    def __init__(self,manuf_date,exp_date):
        self.manuf_date = manuf_date
        self.exp_date = exp_date
        
    def calculate_expiry(self):

        ma = datetime.strptime(self.manuf_date, "%Y-%m-%d")
        ex = datetime.strptime(self.exp_date, "%Y-%m-%d")

        diff = (ex - ma).days

        years = diff // 365
        months = (diff % 365) // 30
        remaining_days = (diff % 365) % 30

        print(f"{years} Years, {months} Months, {remaining_days} Days left for expiry")

p = Product("2025-11-06","2026-06-12")

p.calculate_expiry()
# Out:
# 0 Years, 7 Months, 8 Days left for expiry

# %% [markdown]
# 15. A university wants to automate their admission process. Students are admitted based on the marks scored in the qualifying exam. A student is identified by student id, age and marks in qualifying exam. Data are valid, if:
#
# 	Age is greater than 20
# 	Marks is between 0 and 100 (both inclusive)
# 	A student qualifies for admission, if
#
# 	Age and marks are valid and
# 	Marks is 65 or more
# 	Write a python program to represent the students seeking admission in the university.

# %%
class AdmissionProcess:

    def __init__(self):
        # self.stud_id = stud_id
        # self.age = age
        # self.marks = marks

        while True:
            choice = input('''
            1. Check eligibility
            2. exit
                ''')
            
            if choice == '1':
                self.check_eligibility()
            elif choice == '2':
                break
    
    def check_eligibility(self):
        stud_id = int(input("Enter stundent id: "))
        age = int(input("Enter student age: "))
        marks = int(input("Enter marks obtained: "))

        if age > 20:
            if marks >= 65:
                print("Student is eligible for admission")
            else:
                print("Marks are below criteria")
        else:
            print("Age is not eligible")

                
a = AdmissionProcess()
# Out:
# Marks are below criteria

# %% [markdown]
# 16. Ice-Cream Scoops and Bowl shop
#
# 	Create a class Scoop which has one public property flavor and one private proptery price. Take flavor values during object creation.
#
# 	Create a class Bowl with private prperty scoop_list which will have list of scoopd object.
#
# 	Create a method add_scoops in Bowl class which will add any no of Scoop objects given as parameter and store it in scoops_list.
#
# 	Make getter and setter method for price property.
#
# 	Make a method display to display flavour and price of each Scoop in scoop_list and print total price of the bowl by adding all flavour scoops prices.
#
# 	Make a method sold in both Scoop class and Bowl class to print no of quantity sold.

# %%
class Scoop:

    __counter = 0

    def __init__(self,flavor):
        self.flavor = flavor
        self.__price = None
        Scoop.__counter += 1

    def get_price(self):
        return self.__price
    
    def set_price(self,price):
        self.__price = price

    def __str__(self):
        return "Flavor -> {} and Price -> {}".format(self.flavor,self.__price)
    
    @staticmethod
    def sold():
        return Scoop.__counter

class Bowl:

    __counter = 0

    def __init__(self):
        self.__scoop_list = []
        Bowl.__counter += 1

    def add_scoops(self,*new_scoop):
        for scoop in new_scoop:
            self.__scoop_list.append(scoop)

    def display(self):
        total = 0
        for scoop in self.__scoop_list:
            print(scoop)

            total += scoop.get_price()

        print("Total price: ", total)

    @staticmethod
    def sold():
        return Bowl.__counter
    
choco = Scoop('chocolate')
choco.set_price(100)
print(choco)

berry = Scoop('berry')
berry.set_price(120)
print(berry)

vanilla = Scoop('vanilla')
vanilla.set_price(150)

bowl = Bowl()

bowl. add_scoops(choco) # Giving one parameter
bowl. add_scoops(berry, vanilla) # Multiple

bowl.display()

Scoop.sold()
Bowl.sold()
# Out:
# Flavor -> chocolate and Price -> 100
# Flavor -> berry and Price -> 120
# Flavor -> chocolate and Price -> 100
# Flavor -> berry and Price -> 120
# Flavor -> vanilla and Price -> 150
# Total price:  370
# 1

# %% [markdown]
# 17. Create a Bus child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle:

    def __init__(self,capacity):
        self.capacity = capacity

    def fare_charges(self):
        return self.capacity * 100 

class Bus(Vehicle):

    def __init__(self):
        super().__init__(50)

    def fare_charges(self):
        base_charge =  super().fare_charges()
        main_charge = base_charge * 0.10
        total_fare = base_charge + main_charge
        return total_fare

b = Bus()
print("Total bus fare: ", b.fare_charges())
# Out:
# Total bus fare:  5500.0

# %% [markdown]
# 18. Write a Python class Employee with attributes like emp_id, emp_name, emp_salary, and emp_department and methods like calculate_emp_salary, emp_assign_department, and print_employee_details.
#
# 	Sample Employee Data:
# 	"ADAMS", "E7876", 50000, "ACCOUNTING"
# 	"JONES", "E7499", 45000, "RESEARCH"
# 	"MARTIN", "E7900", 50000, "SALES"
# 	"SMITH", "E7698", 55000, "OPERATIONS"
#
# 	Use 'assign_department' method to change the department of an employee.
# 	Use 'print_employee_details' method to print the details of an employee.
# 	Use 'calculate_emp_salary' method takes two arguments: salary and hours_worked, which is the number of hours worked by the employee. If the number of hours worked is more than 50, the method computes overtime and adds it to the salary. Overtime is calculated as following formula:
# 	overtime = hours_worked - 50
# 	Overtime amount = (overtime * (salary / 50))

# %%
class Employee:
    def __init__(self,emp_id,emp_name,emp_salary,emp_department):
        self.__emp_id = emp_id
        self.emp_name = emp_name
        self.emp_salary = emp_salary
        self.emp_dept = emp_department

    def calculate_emp_salary(self,salary,hours_worked):
        overtime = hours_worked - 50
        overtime_amt = (overtime * (salary/50))

        print("Overtime salary: ", overtime_amt)

        total_salary = salary + overtime_amt
        print("Total salary: ", total_salary)

    def emp_assign_department(self,dept):
        self.emp_dept = dept

    def employee_details(self):
        print("Employee Id: ",self.__emp_id)
        print("Employee name: ",self.emp_name)
        print("Employee Salary: ",self.emp_salary)
        print("Employee department: ",self.emp_dept)

e = Employee(101,"Aman",50000,"Software Development")
e.calculate_emp_salary(50000,75)
e.emp_assign_department("QA")
e.employee_details()
# Out:
# Overtime salary:  25000.0
# Total salary:  75000.0
# Employee Id:  101
# Employee name:  Aman
# Employee Salary:  50000
# Employee department:  QA

# %% [markdown]
# 19. Write a Python class Restaurant with attributes like menu_items, book_table, and customer_orders, and methods like add_item_to_menu, book_tables, and customer_order.
#
# 	Perform the following tasks now:
#
# 	Now add items to the menu.
# 	Make table reservations.
# 	Take customer orders.
# 	Print the menu.
# 	Print table reservations.
# 	Print customer orders.
# 	Note: Use dictionaries and lists to store the data.

# %%
class Restaurant:

    def __init__(self):
        self.menu_items = {}
        self.book_table = []
        self.customer_order = []

    def add_items_to_menu(self,item,price):
        self.menu_items[item] = [price]

    def book_tables(self,table_no):
        self.book_table.append(table_no)

    def customer_orders(self,order):
        self.customer_order.append(order)

    def print_menu(self):
        print("Today's Menu")
        for item, price in self.menu_items.items():
            print(item,":",price)

    def print_reservation(self):
        print("Booked tables: ",self.book_table)

    def print_order(self):
        print("Customer order: ",self.customer_order)

c1 = Restaurant()

c1.add_items_to_menu("Burger",90)
c1.add_items_to_menu("Shawarma",100)

c1.book_tables(12)
c1.book_tables(23)

c1.customer_orders("Shawarma")

c1.print_menu()
c1.print_reservation()
c1.print_order()
# Out:
# Today's Menu
# Burger : [90]
# Shawarma : [100]
# Booked tables:  [12, 23]
# Customer order:  ['Shawarma']

# %% [markdown]
# 20. Write a Python class BankAccount with attributes like account_number, balance, date_of_opening and customer_name, and methods like deposit, withdraw, and check_balance.

# %%
class BankAccount:

    def __init__(self,accountNumber,name,balance,date_of_opening):
        self.accountNumber = accountNumber
        self.name = name
        self.balance = balance
        self.date_of_opening = date_of_opening
        self.__menu()

    def __menu(self):
        while True:
            choice = input('''
            1. Deposit
            2. Withdrawal
            3. Check balance
            4. Exit
            Enter choice: ''')

            if choice == '1':
                self.deposit()
            elif choice == '2':
                self.withdrawal()
            elif choice == '3':
                self.check_balance()
            elif choice == '4':
                print("Thank you!")
                break
            else:
                print("Invalid choice")

    def deposit(self):
        
        name = input("Enter your name: ")
        acc_num = input("Enter your account number: ")
        dep = int(input("Enter the amount: "))

        if name == self.name and acc_num == self.accountNumber:
                self.balance += dep
                print("Avaiable balance: ", self.balance)
        else:
            print("Invalid details")
        self.__menu()


    def withdrawal(self):
        name = input("Enter your name: ")
        acc_num = input("Enter your account number: ")
        amt = int(input("Enter the amount: "))

        if name == self.name and acc_num == self.accountNumber:
            if amt <= self.balance:
                self.balance -= amt
                print("Avaiable balance: ", self.balance)
            else:
                print("Insufficient balance")
        else:
            print("Invalid details")
        self.__menu()


    def check_balance(self):
        print("Avaiable balance: ", self.balance)
        self.__menu()

b = BankAccount('123456','Himanshu',10000,"2012-13-06")
# Out:
# Avaiable balance:  10000
# Thank you!
# Thank you!

# %% [markdown]
# 21. Write a Python class Inventory with attributes like item_id, item_name, stock_count, and price, and methods like add_item, update_item, and check_item_details.

# %%
class Inventory:

    def __init__(self):
        self.item_list = {}

    def add_item(self,item_id,item_name,stock_count,price):

        self.item_list[item_id] = {
            "name": item_name,
            "stock": stock_count,
            "price": price
        }
        print("item is added")

    def update_item(self,item_id,stock_count=None,price=None):
        if item_id in self.item_list:
            if stock_count is not None:
                self.item_list[item_id]["stock"] = stock_count
            if price in self.item_list:
                self.item_list[item_id]["price"] = price
            print("Item updated successfully")
        else:
            print("Item not found")    

    def check_item_details(self,item_id):
        if item_id in self.item_list:
            item = self.item_list[item_id]
            print("Item id: ", item_id)
            print("Item name: ", item["name"])
            print("Item stock: ",item["stock"])
            print("Item price: ", item["price"])
        else:
            print("Item not found")

i = Inventory()


i.add_item(101, "Washing Machine", 10, 40000)
i.add_item(102, "Hair drier", 20, 700)

i.check_item_details(101)

i.update_item(101, stock_count=9, price=45000)

i.check_item_details(101)
# Out:
# item is added
# item is added
# Item id:  101
# Item name:  Washing Machine
# Item stock:  10
# Item price:  40000
# Item updated successfully
# Item id:  101
# Item name:  Washing Machine
# Item stock:  9
# Item price:  40000
